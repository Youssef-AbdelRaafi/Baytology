# %%
# import libaries
import pandas as pd
import os

# %%
# change the current working dir
os.chdir('/home/saad-naeem/Desktop/Level_4/Graduation_project_saad/chatbot/Baytology')

# %%
# read dataset as dataframe
df = pd.read_csv('../Baytology/DataSet/Egypt_Houses_Price.csv')

# %%
# explore data columns
print(f"df_columns: {df.columns}")

# insight -> we have 11 columns
# Out:
# df_columns: Index(['Type', 'Price', 'Bedrooms', 'Bathrooms', 'Area', 'Furnished', 'Level',
#        'Compound', 'Payment_Option', 'Delivery_Date', 'Delivery_Term', 'City'],
#       dtype='object')

# %%
# data describtion
df.info()

# insight -> we should convert every column to spesific datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27361 entries, 0 to 27360
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            27361 non-null  object
#  1   Price           27359 non-null  object
#  2   Bedrooms        27158 non-null  object
#  3   Bathrooms       27190 non-null  object
#  4   Area            26890 non-null  object
#  5   Furnished       27361 non-null  object
#  6   Level           27361 non-null  object
#  7   Compound        27361 non-null  object
#  8   Payment_Option  27361 non-null  object
#  9   Delivery_Date   27361 non-null  object
#  10  Delivery_Term   27361 non-null  object
#  11  City            27361 non-null  object
# dtypes: object(12)
# memory usage: 2.5+ MB

# %%
# see the null values
df.isna().sum()

# insight -> we have to fill this null values
# Out:
# Type                0
# Price               2
# Bedrooms          203
# Bathrooms         171
# Area              471
# Furnished           0
# Level               0
# Compound            0
# Payment_Option      0
# Delivery_Date       0
# Delivery_Term       0
# City                0
# dtype: int64
